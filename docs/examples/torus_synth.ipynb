# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../')

# %% [markdown]
# # 1 Generating blob labels
# - We aim to generate a tensor of blob labels that is size `shape` in all dimensions
# - The returned label tensor is composed of integers with shape (D, H, W)

# %%
import cornucopia as cc
import matplotlib.pyplot as plt
from SynthShapes.shapes import TorusBlobSampler
import torch
from torch import nn
# Out:
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:128: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:147: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad):
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:158: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:177: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad):
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:207: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad):
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:219: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float32)
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:238: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad):
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:252: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, bound, interpolation, dim, inplace):
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:269: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad):
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:280: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, bound, interpolation, dim, inplace):
# /autofs/cluster/octdata2/users/epc28/miniforge3/envs/shapes/lib/python3.9/site-packages/interpol/autograd.py:297: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad):

# %%
labels, mask = TorusBlobSampler(
    major_radius_range=[10, 15],
    return_mask=True
    )()
plt.imshow(labels[0, 32].cpu())

# %% [markdown]
# # 2 Augmenting blobs into background

# %%
import cornucopia as cc
import matplotlib.pyplot as plt
from SynthShapes.shapes import TorusBlobAugmentation
import torch

# %% [markdown]
# ## 2.1 Generating background
# We begin by generating the background labels of shape (1, 64, 64, 64) into which we will blend the blobs.

# %%
base = torch.randn((1, 64, 64, 64))
base = cc.RandomSmoothLabelMap()(base)
base = cc.RandomGaussianMixtureTransform()(base)
plt.imshow(base[0, 32].cpu(), cmap='gray')

# %% [markdown]
# ## 2.2 (OPTIONAL) Define the intensity augmentation for the blobs
# We will now optionally define a transformation which will be applied to **only** blobs. This is important to make sure the blobs have some texture.

# %%
augmentation = torch.nn.Sequential(
    cc.RandomGaussianMixtureTransform(mu=1, sigma=1),
)

# %% [markdown]
# ## 2.3 Augment and view the base tensor & blob mask
# We now use SynthShapes to generate and blend the blobs into the base tensor we made earlier

# %%
augmented_base, mask = TorusBlobAugmentation(
    shape=64,
    alpha=cc.Uniform(0.5, 0.75),
    intensity_shift=cc.Uniform(2, 20),
    augmentation=augmentation,
    return_mask=True
    )(base)

# Transform histogram
augmented_base = cc.QuantileTransform(
    vmin=0.1,
    vmax=0.9,
    pmin=0.1,
    pmax=0.9
    )(augmented_base)

print(torch.unique(augmented_base))

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
# Augmented image slice
ax1.imshow(augmented_base[0, 32].cpu(), cmap='gray')
ax1.set_title("Augmented Image Slice")
ax1.axis('off')
# Torus mask
ax2.imshow(mask[0, 32].cpu(), cmap='gray')
ax2.set_title("Torus Mask")
ax2.axis('off')
# Display fig
plt.tight_layout()
plt.show()
# Out:
# tensor([0.0853, 0.0858, 0.0859,  ..., 1.3334, 1.3724, 1.4089], device='cuda:0')

# %% [markdown]
# ## 2.4 Visualize intensity distribution
# Now let's visualize the distribution of intensities in our synthesized image.

# %%
print(torch.unique(augmented_base))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Image
ax1.imshow(augmented_base[0, 32].cpu(), cmap='gray')
ax1.set_title("Image Slice")
ax1.axis('off')

# Histogram
ax2.hist(augmented_base.flatten().cpu().numpy(), bins=500, density=True, alpha=0.75, color='b')
ax2.set_title("Intensity Frequency Histogram of Volume")
ax2.set_xlabel("Intensity Value")
ax2.set_ylabel("Density")

# Display fig
plt.tight_layout()
plt.show()
# Out:
# tensor([0.0853, 0.0858, 0.0859,  ..., 1.3334, 1.3724, 1.4089], device='cuda:0')
